# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.stats as st

t_true = np.arange(0,273,0.1)
t_data = np.loadtxt('timedata.dat')
x_data = np.loadtxt('data.dat')

# t_data_old = np.loadtxt('timedata_365.dat')
# x_data_old = np.loadtxt('data365.dat')

import parse

x_temp = np.loadtxt('true.dat')
# x_temp = np.loadtxt('true_shift.dat')
x_true = x_temp.reshape(5,3650)
t = x_true[4,:]

# print(x_true[:,0])

# %%
f, ax = plt.subplots(1, figsize=(15,3))
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:blue')
# plt.plot(t_data_old,x_data_old,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,365])
plt.ylim([0,0.025])
plt.xlabel('Time (days)', fontsize=10)
plt.ylabel('I', fontsize=10)
plt.savefig('figures/data.pdf')
plt.close()

# %%
## Model 1

[t,x_mean,x_var] =  parse.parseXML('Model1SS-state-estimation0.xml')

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[0,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[0,:]+1.96*np.sqrt(x_var[0,:]),x_mean[0,:]-1.96*np.sqrt(x_var[0,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[0,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,364])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('S', fontsize=10)
plt.savefig('figures/m1_s.pdf')
plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[1,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[1,:]+1.96*np.sqrt(x_var[4,:]),x_mean[1,:]-1.96*np.sqrt(x_var[4,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[1,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,0.06])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('I', fontsize=10)
plt.savefig('figures/m1_i.pdf')
plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[2,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[2,:]+1.96*np.sqrt(x_var[8,:]),x_mean[2,:]-1.96*np.sqrt(x_var[8,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[2,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,364])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('R', fontsize=10)
plt.savefig('figures/m1_r.pdf')
plt.close()

# %%
## Model 2

[t,x_mean,x_var] =  parse.parseXML('Model2SS-state-estimation0.xml')

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[0,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[0,:]+1.96*np.sqrt(x_var[0,:]),x_mean[0,:]-1.96*np.sqrt(x_var[0,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[0,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,364])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('S', fontsize=10)
plt.savefig('figures/m2_s.pdf')
plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[1,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[1,:]+1.96*np.sqrt(x_var[5,:]),x_mean[1,:]-1.96*np.sqrt(x_var[5,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[1,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,0.06])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('I', fontsize=10)
plt.savefig('figures/m2_i.pdf')
plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[2,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[2,:]+1.96*np.sqrt(x_var[10,:]),x_mean[2,:]-1.96*np.sqrt(x_var[10,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[2,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,364])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('R', fontsize=10)
plt.savefig('figures/m2_r.pdf')
plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[3,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[3,:]+1.96*np.sqrt(x_var[15,:]),x_mean[3,:]-1.96*np.sqrt(x_var[15,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[3,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,0.25])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel(r'$\beta$', fontsize=10)
plt.savefig('figures/m2_b.pdf')
plt.close()

# %%
## Model 2 & 3

[t,x2_mean,x2_var] =  parse.parseXML('Model2SS-state-estimation0.xml')
[t,x3_mean,x3_var] =  parse.parseXML('Model3SS-state-estimation0.xml')

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x3_mean[1,:],linewidth=2,c='tab:orange')
plt.fill_between(t,x3_mean[1,:]+1.96*np.sqrt(x3_var[5,:]),x3_mean[1,:]-1.96*np.sqrt(x3_var[5,:]),facecolor='tab:orange',alpha=0.5)
plt.plot(t,x2_mean[1,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x2_mean[1,:]+1.96*np.sqrt(x2_var[5,:]),x2_mean[1,:]-1.96*np.sqrt(x2_var[5,:]),facecolor='w',alpha=1)
plt.fill_between(t,x2_mean[1,:]+1.96*np.sqrt(x2_var[5,:]),x2_mean[1,:]-1.96*np.sqrt(x2_var[5,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[1,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,0.08])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('I', fontsize=10)
plt.savefig('figures/m23_i.pdf')
plt.close()


f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x3_mean[3,:],linewidth=2,c='tab:orange')
plt.fill_between(t,x3_mean[3,:]+1.96*np.sqrt(x3_var[15,:]),x3_mean[3,:]-1.96*np.sqrt(x3_var[15,:]),facecolor='tab:orange',alpha=0.5)
plt.plot(t,x2_mean[3,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x2_mean[3,:]+1.96*np.sqrt(x2_var[15,:]),x2_mean[3,:]-1.96*np.sqrt(x2_var[15,:]),facecolor='w',alpha=1)
plt.fill_between(t,x2_mean[3,:]+1.96*np.sqrt(x2_var[15,:]),x2_mean[3,:]-1.96*np.sqrt(x2_var[15,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[3,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,0.25])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel(r'$\beta$', fontsize=10)
plt.savefig('figures/m23_b.pdf')
plt.close()

# %%
## Model 3

[t,x_mean,x_var] =  parse.parseXML('Model3SS-state-estimation0.xml')

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[0,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[0,:]+1.96*np.sqrt(x_var[0,:]),x_mean[0,:]-1.96*np.sqrt(x_var[0,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[0,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,364])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('S', fontsize=10)
plt.savefig('figures/m3_s.pdf')
plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[1,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[1,:]+1.96*np.sqrt(x_var[5,:]),x_mean[1,:]-1.96*np.sqrt(x_var[5,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[1,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,0.1])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('I', fontsize=10)
plt.savefig('figures/m3_i.pdf')
plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[2,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[2,:]+1.96*np.sqrt(x_var[10,:]),x_mean[2,:]-1.96*np.sqrt(x_var[10,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[2,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,364])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('R', fontsize=10)
plt.savefig('figures/m3_r.pdf')
plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[3,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[3,:]+1.96*np.sqrt(x_var[15,:]),x_mean[3,:]-1.96*np.sqrt(x_var[15,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[3,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,0.25])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel(r'$\beta$', fontsize=10)
plt.savefig('figures/m3_b.pdf')
plt.close()

# %%
## Model 4

[t,x_mean,x_var] =  parse.parseXML('Model4SS-state-estimation0.xml')

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[0,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[0,:]+1.96*np.sqrt(x_var[0,:]),x_mean[0,:]-1.96*np.sqrt(x_var[0,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[0,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,x_data,'o',alpha=0.5,c='tab:red')
plt.grid(True)
plt.xlim([0,364])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('S', fontsize=10)
plt.savefig('figures/m4_s.pdf')
plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[1,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[1,:]+1.96*np.sqrt(x_var[5,:]),x_mean[1,:]-1.96*np.sqrt(x_var[5,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[1,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
# plt.plot(t_data,4*x_data,'o',alpha=0.2,c='tab:red')
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,0.08])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('I', fontsize=10)
plt.savefig('figures/m4_i.pdf')
plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[2,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[2,:]+1.96*np.sqrt(x_var[10,:]),x_mean[2,:]-1.96*np.sqrt(x_var[10,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[2,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,364])
# plt.ylim([-15,15])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel('R', fontsize=10)
plt.savefig('figures/m4_r.pdf')
plt.close()

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,x_mean[3,:],linewidth=2,c='tab:blue')
plt.fill_between(t,x_mean[3,:]+1.96*np.sqrt(x_var[15,:]),x_mean[3,:]-1.96*np.sqrt(x_var[15,:]),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[3,:],c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'sk:',linewidth=1.5)
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,0.25])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel(r'$\beta$', fontsize=10)
plt.savefig('figures/m4_b.pdf')
plt.close()

# %%
re_mu = np.zeros(len(x_mean[0,:]))
re_sigma = np.zeros(len(x_mean[0,:]))

for ii in range(len(x_mean[0,:])):
  Mu = [x_mean[0,ii],x_mean[3,ii]]
  Sigma = [[x_var[0,ii],x_var[3,ii]],[x_var[12,ii],x_var[15,ii]]]

  s_beta = np.random.multivariate_normal(Mu,Sigma,1000)

  re_mu[ii] = np.mean(14*s_beta[:,0]*s_beta[:,1])
  re_sigma[ii] = np.var(14*s_beta[:,0]*s_beta[:,1])

f, ax = plt.subplots(1, figsize=(15,3))
plt.plot(t,re_mu,linewidth=2,c='tab:blue')
plt.fill_between(t,re_mu+1.96*np.sqrt(re_sigma),re_mu-1.96*np.sqrt(re_sigma),facecolor='tab:blue',alpha=0.5)
plt.plot(x_true[4,:],x_true[0,:]*x_true[3,:]*14,c='tab:red',linestyle='--')
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
for ii in range(len(re_mu)-1):
  if (re_mu[ii+1]-1)/(re_mu[ii]-1) < 0:
    plt.plot([t[ii],t[ii]],[0,3])
plt.grid(True)
plt.xlim([0,364])
plt.ylim([0,3])
plt.xlabel('Time (days)', fontsize=12)
# plt.ylabel(r'$R_e(t)$', fontsize=10)
plt.savefig('figures/m4_re.pdf')
plt.close()

# %%
Ndays = 36
tdata = np.arange(0,Ndays)
sampFac = 10 # sample every sampFac time step
dt = 1/10 # timestep
tgrd = 10*Ndays # time integration grid
tlist = np.zeros((1,tgrd))
tlist[0,:]  = np.linspace(0,Ndays,tgrd) # Define time axis

gamma = 1/14
Nsamp = 500

i, b = np.zeros((Nsamp,tgrd)), np.zeros((Nsamp,tgrd))
Yforecast = np.zeros((4,tgrd))

samp = np.random.multivariate_normal(x_mean[:,-1], np.reshape(x_var[:,-1],[4,4]), size=Nsamp)

np.random.seed(123)
for ii in range(Nsamp):
  Yforecast[:,0] = samp[ii]
  for kk in range(1,tgrd):
    Yforecast[0,kk] = Yforecast[0,kk-1] + dt*(-Yforecast[3,kk-1]*Yforecast[0,kk-1]*Yforecast[1,kk-1])
    Yforecast[1,kk] = Yforecast[1,kk-1] + dt*(Yforecast[3,kk-1]*Yforecast[0,kk-1]*Yforecast[1,kk-1] - gamma*Yforecast[1,kk-1])
    Yforecast[2,kk] = Yforecast[2,kk-1] + dt*(gamma*Yforecast[1,kk-1])
    Yforecast[3,kk] = Yforecast[3,kk-1] + 0.005219456201023147*np.sqrt(dt)*np.random.normal(0,1)

  i[ii,:] = Yforecast[1,:]
  b[ii,:] = Yforecast[3,:]

mean_i = np.mean(i,axis=0)
mean_b = np.mean(b,axis=0)

f, ax = plt.subplots(1, figsize=(5,3))#15,3
plt.plot(tlist[0,:],i.T,linewidth=0.1,alpha=0.5,c='tab:blue',zorder=2)
plt.plot(tlist[0,:],mean_i,linewidth=2,c='tab:blue',zorder=3)
plt.plot(x_true[4,3650:4001]-365,x_true[1,3650:4001],linewidth=2,c='tab:red',linestyle='--',zorder=4)
# plt.fill_between(t_pred,x_mean_pred[1,:]+1.96*np.sqrt(x_var_pred[5,:]),x_mean_pred[1,:]-1.96*np.sqrt(x_var_pred[5,:]),facecolor='tab:blue',alpha=0.25)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xticks([0,7,14,21,28])
plt.xlim([0,28])
plt.ylim([0,0.1])
plt.xlabel('Days since last observation', fontsize=12)
# plt.ylabel(r'Active infections ($I$ compartment)', fontsize=10)
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.25), fancybox=True, shadow=True, ncol=3, fontsize=12)
plt.savefig('figures/forecast_i.pdf',bbox_inches='tight')
plt.close()

f, ax = plt.subplots(1, figsize=(5,3))#15,3
plt.plot(tlist[0,0:370],b.T,linewidth=0.1,alpha=0.5,c='tab:blue',zorder=2)
plt.plot(tlist[0,:],mean_b,linewidth=2,c='tab:blue',zorder=3)
plt.plot(x_true[4,3650:4001]-365,x_true[3,3650:4001],linewidth=2,c='tab:red',linestyle='--',zorder=4)
# plt.fill_between(t_pred,x_mean_pred[3,:]+1.96*np.sqrt(x_var_pred[15,:]),x_mean_pred[3,:]-1.96*np.sqrt(x_var_pred[15,:]),facecolor='tab:blue',alpha=0.25)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xticks([0,7,14,21,28])
plt.xlim([0,28])
plt.ylim([0,0.25])
plt.xlabel('Days since last observation', fontsize=12)
# plt.ylabel(r'Transmission rate (parameter $\beta$)', fontsize=10)
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.25), fancybox=True, shadow=True, ncol=3, fontsize=12)
plt.savefig('figures/forecast_beta.pdf',bbox_inches='tight')
plt.close()

# %%
skip = 10
Ndays = 36
tdata = np.arange(0,Ndays)
sampFac = 10 # sample every sampFac time step
dt = 1/10 # timestep
tgrd = 10*Ndays # time integration grid
tlist = np.zeros((1,tgrd))
tlist[0,:]  = np.linspace(0,Ndays,tgrd) # Define time axis

gamma = 1/14
Nsamp = 500*skip

i, b = np.zeros((Nsamp,tgrd)), np.zeros((Nsamp,tgrd))
Yforecast = np.zeros((4,tgrd))

samp = np.random.multivariate_normal(x_mean[:,-1], np.reshape(x_var[:,-1],[4,4]), size=Nsamp)

np.random.seed(123)
for ii in range(Nsamp):
  Yforecast[:,0] = samp[ii]
  for kk in range(1,tgrd):
    Yforecast[0,kk] = Yforecast[0,kk-1] + dt*(-Yforecast[3,kk-1]*Yforecast[0,kk-1]*Yforecast[1,kk-1])
    Yforecast[1,kk] = Yforecast[1,kk-1] + dt*(Yforecast[3,kk-1]*Yforecast[0,kk-1]*Yforecast[1,kk-1] - gamma*Yforecast[1,kk-1])
    Yforecast[2,kk] = Yforecast[2,kk-1] + dt*(gamma*Yforecast[1,kk-1])
    Yforecast[3,kk] = Yforecast[3,kk-1] + 0.005219456201023147*np.sqrt(dt)*np.random.normal(0,1)

  i[ii,:] = Yforecast[1,:]
  b[ii,:] = Yforecast[3,:]

mean_i = np.mean(i,axis=0)
mean_b = np.mean(b,axis=0)

Igrd = np.linspace(0,0.1,201)
Ipdf_0 = st.gaussian_kde(i[:,0],bw_method = 0.2)
Ipdf_7 = st.gaussian_kde(i[:,70],bw_method = 0.2)
Ipdf_14 = st.gaussian_kde(i[:,140],bw_method = 0.2)
Ipdf_21 = st.gaussian_kde(i[:,210],bw_method = 0.2)
Ipdf_28 = st.gaussian_kde(i[:,280],bw_method = 0.2)
Imax = np.max([Ipdf_0(Igrd),Ipdf_7(Igrd),Ipdf_14(Igrd),Ipdf_21(Igrd),Ipdf_28(Igrd)])

Bgrd = np.linspace(0,0.25,201)
Bpdf_0 = st.gaussian_kde(b[:,0],bw_method = 0.2)
Bpdf_7 = st.gaussian_kde(b[:,70],bw_method = 0.2)
Bpdf_14 = st.gaussian_kde(b[:,140],bw_method = 0.2)
Bpdf_21 = st.gaussian_kde(b[:,210],bw_method = 0.2)
Bpdf_28 = st.gaussian_kde(b[:,280],bw_method = 0.2)
Bmax = np.max([Bpdf_0(Bgrd),Bpdf_7(Bgrd),Bpdf_14(Bgrd),Bpdf_21(Bgrd),Ipdf_28(Bgrd)])

f, ax = plt.subplots(1, figsize=(5,3))#15,3
plt.plot(tlist[0,:],i[::skip].T,linewidth=0.1,alpha=0.5,c='tab:blue',zorder=2)
plt.plot(tlist[0,:],mean_i,linewidth=2,c='tab:blue',zorder=3)
plt.plot(x_true[4,3650:4001]-365,x_true[1,3650:4001],linewidth=2,c='tab:red',linestyle='--',zorder=4)
plt.plot(Ipdf_0(Igrd)*6/Imax,Igrd,linewidth=2,c='tab:green',zorder=3)
plt.plot(7+Ipdf_7(Igrd)*6/Imax,Igrd,linewidth=2,c='tab:green',zorder=3)
plt.plot(14+Ipdf_14(Igrd)*6/Imax,Igrd,linewidth=2,c='tab:green',zorder=3)
plt.plot(21+Ipdf_21(Igrd)*6/Imax,Igrd,linewidth=2,c='tab:green',zorder=3)
plt.plot(28+Ipdf_28(Igrd)*6/Imax,Igrd,linewidth=2,c='tab:green',zorder=3)
# plt.fill_between(t_pred,x_mean_pred[1,:]+1.96*np.sqrt(x_var_pred[5,:]),x_mean_pred[1,:]-1.96*np.sqrt(x_var_pred[5,:]),facecolor='tab:blue',alpha=0.25)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xticks([0,7,14,21,28])
plt.xlim([0,28])
plt.ylim([0,0.1])
plt.xlabel('Days since last observation', fontsize=12)
# plt.ylabel(r'Active infections ($I$ compartment)', fontsize=10)
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.25), fancybox=True, shadow=True, ncol=3, fontsize=12)
plt.savefig('figures/forecast_i_uq.pdf',bbox_inches='tight')
plt.close()

f, ax = plt.subplots(1, figsize=(5,3))#15,3
plt.plot(tlist[0,0:370],b[::skip].T,linewidth=0.1,alpha=0.5,c='tab:blue',zorder=2)
plt.plot(tlist[0,:],mean_b,linewidth=2,c='tab:blue',zorder=3)
plt.plot(x_true[4,3650:4001]-365,x_true[3,3650:4001],linewidth=2,c='tab:red',linestyle='--',zorder=4)
plt.plot(Bpdf_0(Bgrd)*6/Bmax,Bgrd,linewidth=2,c='tab:green',zorder=3)
plt.plot(7+Bpdf_7(Bgrd)*6/Bmax,Bgrd,linewidth=2,c='tab:green',zorder=3)
plt.plot(14+Bpdf_14(Bgrd)*6/Bmax,Bgrd,linewidth=2,c='tab:green',zorder=3)
plt.plot(21+Bpdf_21(Bgrd)*6/Bmax,Bgrd,linewidth=2,c='tab:green',zorder=3)
plt.plot(28+Bpdf_28(Bgrd)*6/Bmax,Bgrd,linewidth=2,c='tab:green',zorder=3)
# plt.fill_between(t_pred,x_mean_pred[3,:]+1.96*np.sqrt(x_var_pred[15,:]),x_mean_pred[3,:]-1.96*np.sqrt(x_var_pred[15,:]),facecolor='tab:blue',alpha=0.25)
# plt.plot([10,10],[-100,100],'k:',linewidth=1.5)
plt.grid(True)
plt.xticks([0,7,14,21,28])
plt.xlim([0,28])
plt.ylim([0,0.25])
plt.xlabel('Days since last observation', fontsize=12)
# plt.ylabel(r'Transmission rate (parameter $\beta$)', fontsize=10)
# ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.25), fancybox=True, shadow=True, ncol=3, fontsize=12)
plt.savefig('figures/forecast_beta_uq.pdf',bbox_inches='tight')
plt.close()
